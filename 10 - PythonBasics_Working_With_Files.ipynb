# %%
with open('pi_digits.txt') as file_object:
    contents = file_object.read()
print(contents)
# Out:
# 3.1415926535
#   8979323846
#   2643383279

# %%
type(file_object)
# Out:
# _io.TextIOWrapper

# %%
type(contents)
# Out:
# str

# %%
with open('pi_digits.txt') as file_object:
    contents = file_object.read()
print(contents.strip())  #revoming the extra blank line
# Out:
# 3.1415926535
#   8979323846
#   2643383279

# %%
#read line by line
filename ='pi_digits.txt'

with open(filename) as file_object:
    lcounter=1
    for line in file_object:
        print(lcounter, ': ', line.strip())
        lcounter += 1
# Out:
# 1 :  3.1415926535
# 2 :  8979323846
# 3 :  2643383279

# %%
#readlines() method makes a list of lines
filename ='pi_digits.txt'

with open(filename) as file_object:
    lines = file_object.readlines()
    for line in lines:
        print(line.strip())
# Out:
# 3.1415926535
# 8979323846
# 2643383279

# %%
#working with file contents
#concatinate the contents

filename ='pi_digits.txt'

with open(filename) as file_object:
    lines = file_object.readlines()
    
pi_string=''
for line in lines:
        pi_string += line.strip()

print(pi_string)
print(len(pi_string))
# Out:
# 3.141592653589793238462643383279
# 32

# %%
filename = 'pi_million_digits.txt'

with open(filename) as file_object:
    lines = file_object.readlines()
pi_string=''
for line in lines:
    pi_string += line.strip()

print(f'{pi_string[:52]}...')
print(len(pi_string))
# Out:
# 3.14159265358979323846264338327950288419716939937510...
# 1000002

# %%
#birthday
filename ='pi_million_digits.txt'

with open(filename) as file_object:
    lines = file_object.readlines()
pi_string=''
for line in lines:
    pi_string += line.strip()
    
birthday = input('Enter your birthday, in the form mmddyy: ')
if birthday in pi_string:
    print('Your birthday appears in the first million digits of pi!')
else:
    print('Your birthday doses not appears in the first million digits of pi!')
# Out:
# Enter your birthday, in the form mmddyy: 120300
# Your birthday appears in the first million digits of pi!

# %%
#write to a file
filename = 'programming.txt'

with open(filename, 'w') as file_object: # 'w' for write , 'a' for append
    file_object.write('I also love finding meaning in large datasets. \n')
    file_object.write('I love creating apps that can run in a browser. \n')

# %%
#csv
import csv
with open ('./Popular_Baby_Names.csv', newline="") as csvfile:
    reader=csv.DictReader(csvfile)
    for row in reader:
        print(row["Child's First Name"], row['Count'])

print(type(reader))
print(type(row))
# Out:
# GERALDINE 13
# GIA 21
# GIANNA 49
# GISELLE 38
# GRACE 36
# GUADALUPE 26
# HAILEY 126
# HALEY 14
# HANNAH 17
# HAYLEE 17
# HAYLEY 13
# HAZEL 10
# HEAVEN 15
# HEIDI 15
# HEIDY 16
# HELEN 13
# IMANI 11
# INGRID 11
# IRENE 11
# IRIS 10
# ISABEL 28
# ISABELA 10
# ISABELLA 331
# ISABELLE 18
# ISIS 13
# ITZEL 27
# IZABELLA 23
# JACQUELINE 30
# JADA 21
# JADE 50
# JAELYNN 11
# JAMIE 11
# JANELLE 12
# JASLENE 11
# JASMIN 20
# JASMINE 41
# JAYDA 10
# JAYLA 33
# JAYLAH 12
# JAYLEEN 51
# JAYLENE 22
# JAYLIN 13
# JAYLYN 10
# JAZLYN 16
# JAZMIN 24
# JAZMINE 14
# JENNIFER 59
# JESSICA 46
# JIMENA 11
# JOCELYN 46
# JOHANNA 12
# JOSELYN 30
# JULIA 22
# JULIANA 16
# JULIANNA 21
# JULIET 20
# JULIETTE 15
# JULISSA 16
# KAELYN 11
# KAILEY 20
# KAILYN 11
# KAITLYN 31
# KAMILA 36
# KAREN 41
# KARLA 25
# KATE 27
# KATELYN 23
# KATELYNN 10
# KATHERINE 60
# KATIE 12
# KAYLA 62
# KAYLEE 83
# KAYLEEN 19
# KAYLEIGH 10
# KAYLIE 15
# KAYLIN 12
# KEILY 17
# KELLY 41
# KEYLA 12
# KHLOE 57
# KIARA 36
# ...

# %%
#access modes r, w, a, r+, w+. etc
with open ('./Popular_Baby_Names.csv','a',  newline="") as csvfile:
    fieldnames = ["Year of Birth","Gender","Ethnicity","Child's First Name","Count","Rank"]
    writer =csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerow(
        {
        "Year of Birth": 2011,
        "Gender": 'MALE',
        "Ethnicity": 'HISPANIC',
        "Child's First Name": 'HAMZA',
        "Count": 1,
        "Rank": 102}
    )

# %%
with open ('./Popular_Baby_Names.csv', newline="") as csvfile:
    reader=csv.DictReader(csvfile)
    for row in reader:
        print(row["Child's First Name"], row['Count'])
# Out:
# GERALDINE 13
# GIA 21
# GIANNA 49
# GISELLE 38
# GRACE 36
# GUADALUPE 26
# HAILEY 126
# HALEY 14
# HANNAH 17
# HAYLEE 17
# HAYLEY 13
# HAZEL 10
# HEAVEN 15
# HEIDI 15
# HEIDY 16
# HELEN 13
# IMANI 11
# INGRID 11
# IRENE 11
# IRIS 10
# ISABEL 28
# ISABELA 10
# ISABELLA 331
# ISABELLE 18
# ISIS 13
# ITZEL 27
# IZABELLA 23
# JACQUELINE 30
# JADA 21
# JADE 50
# JAELYNN 11
# JAMIE 11
# JANELLE 12
# JASLENE 11
# JASMIN 20
# JASMINE 41
# JAYDA 10
# JAYLA 33
# JAYLAH 12
# JAYLEEN 51
# JAYLENE 22
# JAYLIN 13
# JAYLYN 10
# JAZLYN 16
# JAZMIN 24
# JAZMINE 14
# JENNIFER 59
# JESSICA 46
# JIMENA 11
# JOCELYN 46
# JOHANNA 12
# JOSELYN 30
# JULIA 22
# JULIANA 16
# JULIANNA 21
# JULIET 20
# JULIETTE 15
# JULISSA 16
# KAELYN 11
# KAILEY 20
# KAILYN 11
# KAITLYN 31
# KAMILA 36
# KAREN 41
# KARLA 25
# KATE 27
# KATELYN 23
# KATELYNN 10
# KATHERINE 60
# KATIE 12
# KAYLA 62
# KAYLEE 83
# KAYLEEN 19
# KAYLEIGH 10
# KAYLIE 15
# KAYLIN 12
# KEILY 17
# KELLY 41
# KEYLA 12
# KHLOE 57
# KIARA 36
# ...

# %%
#csv dialect
with open('Popular_Baby_Names_tab.csv', newline="") as csvfile:
    reader=csv.DictReader(csvfile, delimiter='\t') #delimiter is tab
    for row in reader:
        print(row["Child's First Name"], row['Count'])
# Out:
# Geraldine 13
# Hamza 46
# Badr 64
# Giselle 12
# Grace 7

# %%
#json file

import json
js = json.dumps(['foo', {'bar':('baz', None, 1.0, 2)}]) # s means string

# %%
type(js)
# Out:
# str

# %%
print(js)
# Out:
# ["foo", {"bar": ["baz", null, 1.0, 2]}]

# %%
images="""
      {
        "Images": [ 
        {
            "Title" : "High View",
            "Width":  800,
            "Height": 600,
            "Title":  "View from 15th Floor",
            "Thumbnail": {
                "Url":    "http://www.example.com/image/481989943",
                "Height": 125,
                "Width":  100
            },
            "Animated" : false,
            "IDs": [116, 943, 234, 38793]
          },
          {
            "Title" : "Ground View",
            "Width":  800,
            "Height": 600,
            "Title":  "View from 1th Floor",
            "Thumbnail": {
                "Url":    "http://www.example.com/image/481989943",
                "Height": 125,
                "Width":  100
            },
            "Animated" : false,
            "IDs": [118, 943, 834, 38993]
          }]
      }

"""

# %%
data=json.loads(images)
print(data)
# Out:
# {'Images': [{'Title': 'View from 15th Floor', 'Width': 800, 'Height': 600, 'Thumbnail': {'Url': 'http://www.example.com/image/481989943', 'Height': 125, 'Width': 100}, 'Animated': False, 'IDs': [116, 943, 234, 38793]}, {'Title': 'View from 1th Floor', 'Width': 800, 'Height': 600, 'Thumbnail': {'Url': 'http://www.example.com/image/481989943', 'Height': 125, 'Width': 100}, 'Animated': False, 'IDs': [118, 943, 834, 38993]}]}

# %%
type(data)
# Out:
# dict

# %%
type(data['Images'])
# Out:
# list

# %%
for image in data["Images"]:
    print(image)
    print('____________________________ \n')
# Out:
# {'Title': 'View from 15th Floor', 'Width': 800, 'Height': 600, 'Thumbnail': {'Url': 'http://www.example.com/image/481989943', 'Height': 125, 'Width': 100}, 'Animated': False, 'IDs': [116, 943, 234, 38793]}
# ____________________________
#
# {'Title': 'View from 1th Floor', 'Width': 800, 'Height': 600, 'Thumbnail': {'Url': 'http://www.example.com/image/481989943', 'Height': 125, 'Width': 100}, 'Animated': False, 'IDs': [118, 943, 834, 38993]}
# ____________________________

# %%
for image in data["Images"]:
    print(image['Title'])
    print('____________________________ \n')

# %%
for image in data["Images"]:
    del image['Thumbnail']
    print(image)
    print('____________________________ \n')
# Out:
# {'Title': 'View from 15th Floor', 'Width': 800, 'Height': 600, 'Animated': False, 'IDs': [116, 943, 234, 38793]}
# ____________________________
#
# {'Title': 'View from 1th Floor', 'Width': 800, 'Height': 600, 'Animated': False, 'IDs': [118, 943, 834, 38993]}
# ____________________________

# %%
for image in data["Images"]:
    print(image["Title"], image["Width"], image["Height"])
    print('____________________________ \n')
# Out:
# View from 15th Floor 800 600
# ____________________________
#
# View from 1th Floor 800 600
# ____________________________

# %%
#dump
new_data=json.dumps(data, indent=2)
print(new_data)
# Out:
# {
#   "Images": [
#     {
#       "Title": "View from 15th Floor",
#       "Width": 800,
#       "Height": 600,
#       "Animated": false,
#       "IDs": [
#         116,
#         943,
#         234,
#         38793
#       ]
#     },
#     {
#       "Title": "View from 1th Floor",
#       "Width": 800,
#       "Height": 600,
#       "Animated": false,
#       "IDs": [
#         118,
#         943,
#         834,
#         38993
#       ]
#     }
#   ]
# }

# %%
#states
filename='us_states.json'
with open(filename) as f:
    us_states_data= json.load(f)
    for state in us_states_data['states']:
        print(state)
# Out:
# {'abbr': 'AL', 'name': 'Alabama', 'capital': 'Montgomery', 'lat': '32.361538', 'long': '-86.279118'}
# {'abbr': 'AK', 'name': 'Alaska', 'capital': 'Juneau', 'lat': '58.301935', 'long': '-134.419740'}
# {'abbr': 'AZ', 'name': 'Arizona', 'capital': 'Phoenix', 'lat': '33.448457', 'long': '-112.073844'}
# {'abbr': 'AR', 'name': 'Arkansas', 'capital': 'Little Rock', 'lat': '34.736009', 'long': '-92.331122'}
# {'abbr': 'CA', 'name': 'California', 'capital': 'Sacramento', 'lat': '38.555605', 'long': '-121.468926'}
# {'abbr': 'CO', 'name': 'Colorado', 'capital': 'Denver', 'lat': '39.7391667', 'long': '-104.984167'}
# {'abbr': 'CT', 'name': 'Connecticut', 'capital': 'Hartford', 'lat': '41.767', 'long': '-72.677'}
# {'abbr': 'DE', 'name': 'Delaware', 'capital': 'Dover', 'lat': '39.161921', 'long': '-75.526755'}
# {'abbr': 'FL', 'name': 'Florida', 'capital': 'Tallahassee', 'lat': '30.4518', 'long': '-84.27277'}
# ...
